# %% [markdown]
# # PANDAS

# %%
#Creating numPy and pandas Package
import pandas as pd
import numpy as np

# %%
value=pd.DataFrame(np.arange(0,20).reshape(5,4),index=['Row1','Row2','Row3','Row4','Row5'],columns=['Column1','Column2','Column3','Column4'])

# %%
value.head()
# Out:
#       Column1  Column2  Column3  Column4
# Row1        0        1        2        3
# Row2        4        5        6        7
# Row3        8        9       10       11
# Row4       12       13       14       15
# Row5       16       17       18       19

# %%
 ## accessing the elements
    ## 1. .loc 2. .iloc
type(value.loc['Row1'])
# Out:
# pandas.core.series.Series

# %%
type(value.iloc[0:3,0:2])
# Out:
# pandas.core.frame.DataFrame

# %%
value.iloc[:,1:].values
# Out:
# array([[ 1,  2,  3],
#        [ 5,  6,  7],
#        [ 9, 10, 11],
#        [13, 14, 15],
#        [17, 18, 19]])

# %%
value.isnull().sum()
# Out:
# Column1    0
# Column2    0
# Column3    0
# Column4    0
# dtype: int64

# %%
value['Column1'].value_counts()
# Out:
# 0     1
# 4     1
# 8     1
# 12    1
# 16    1
# Name: Column1, dtype: int64

# %%
value['Column2'].unique()
# Out:
# array([ 1,  5,  9, 13, 17])

# %% [markdown]
# # READING IN PANDAS

# %%
value.to_csv('Test1.CSV')

# %%
test_value=pd.read_csv('Test1.CSV',sep=',')

# %%
test_value.head()
# Out:
#   Unnamed: 0  Column1  Column2  Column3  Column4
# 0       Row1        0        1        2        3
# 1       Row2        4        5        6        7
# 2       Row3        8        9       10       11
# 3       Row4       12       13       14       15
# 4       Row5       16       17       18       19

# %% [markdown]
# ## CSV

# %%
from io import StringIO, BytesIO

# %%
data =('col1,col2,col3\n'
      'x,y,1\n'
      'a,b,2\n'
      'c,d,3')

# %%
type(data)
# Out:
# str

# %%
pd.read_csv(StringIO(data))
# Out:
#   col1 col2  col3
# 0    x    y     1
# 1    a    b     2
# 2    c    d     3

# %%
## Read From specific Columns

# %%
pd.read_csv(StringIO(data),usecols=['col1','col3'])
# Out:
#   col1  col3
# 0    x     1
# 1    a     2
# 2    c     3

# %%
data1=('a,b,c\n'
      '1,apple,bat\n'
      '2,orange,ball')

# %%
data1
# Out:
# 'a,b,c\n1,apple,bat\n2,orange,ball'

# %%
pd.read_csv(StringIO(data1))
# Out:
#    a       b     c
# 0  1   apple   bat
# 1  2  orange  ball

# %%
pd.read_csv(StringIO(data1),index_col=False)
# Out:
#    a       b     c
# 0  1   apple   bat
# 1  2  orange  ball

# %%
pd.read_csv(StringIO(data1),usecols=['b','c'],index_col=False)
# Out:
#         b     c
# 0   apple   bat
# 1  orange  ball
